# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.plot([3,4,5,6])
plt.title('가나다')
# Out:
# Text(0.5, 1.0, '가나다')

# %% [markdown]
# [작업3]

# %%
import csv

data = []
f = open('울산광역시 남구_코로나19_확진자_및_사망자_현황_20220126.csv', 'r', encoding='euc-kr')
reader = csv.reader(f)
for row in reader:

    data.append(row)
f.close()

# File is automatically closed when exiting the 'with' block

# %% [markdown]
# [작업4] 자료분리

# %%
header=data[0]; local=data[1:]
label=[]
for x in local:
    label.append(x[2]+'-'+x[3])
    
num=[]
for x in local:
    num.append(x[4:6])

# %% [markdown]
# 작업5: num의 확진자수와 사망자수가 문자로 되어 있어서 ‘8’, ‘0’   이 자료를 8과 0의 숫자로 변경해야함.

# %%
#### num에 있는 자료가 문자로 들어가 있음.
new_num=[]
for x in num:
    line=[]

    for y in x:
        line.append(int(y))
    new_num.append(line)
new_num
# Out:
# [[8, 0],
#  [9, 1],
#  [1, 0],
#  [2, 0],
#  [18, 0],
#  [20, 0],
#  [2, 0],
#  [9, 0],
#  [292, 22],
#  [28, 8],
#  [11, 1],
#  [18, 0],
#  [259, 0],
#  [255, 1],
#  [58, 0],
#  [121, 0],
#  [292, 0],
#  [316, 5],
#  [87, 0],
#  [91, 1],
#  [299, 1],
#  [327, 2]]

# %% [markdown]
# 작업6: 차트 작업에 필요한 숫자계산후 차트

# %%
import numpy as np

세로합=np.sum(new_num,axis=0)
세로합

import matplotlib.pyplot as plt
plt.rc('font', family='Malgun Gothic')

plt.bar(header[4:6],세로합)
plt.show()

# %% [markdown]
# 작업7:차트 작업

# %%
세로합_2020년도=np.sum(new_num[:9],axis=0)
세로합_2021년도=np.sum(new_num[9:21],axis=0)
print(세로합_2020년도)
print(세로합_2021년도)
# Out:
# [361  23]
# [1835   17]

# %%
plt.figure(figsize=(20,5))# 가로세로, 크기 지정
plt.subplot(121)# 1행에 2개의 열중 첫번째 자료임
plt.title('2020년도 확진자, 사망자수')
plt.bar(header[4:6],세로합_2020년도)
#plt.show()
plt.subplot(122)# 1행에 2개의 열중 첫번째 자료임
plt.title('2021년도 확진자, 사망자수')
plt.bar(header[4:6],세로합_2021년도)
plt.show()

# %% [markdown]
# 작업8:차트 작업

# %%
#plt.bar(레이블_2020년도,new_num[:9])
#레이블_2020년도
# 2020 년도 확잔자 수만 분리
data_2020=[]
for x in new_num[:9]:
    data_2020.append(x[0])
print(data_2020)
print(label[:9])
plt.barh(label[:9],data_2020)
plt.show()
# Out:
# [8, 9, 1, 2, 18, 20, 2, 9, 292]
# ['2020-02', '2020-03', '2020-04', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12']

# %%
data_2020=[]
for x in new_num[9:]:
    data_2020.append(x[0])
print(data_2020)
print(label[:9])

plt.barh(label[9:],data_2020)
# Out:
# [28, 11, 18, 259, 255, 58, 121, 292, 316, 87, 91, 299, 327]
# ['2020-02', '2020-03', '2020-04', '2020-07', '2020-08', '2020-09', '2020-10', '2020-11', '2020-12']
# <BarContainer object of 13 artists>
