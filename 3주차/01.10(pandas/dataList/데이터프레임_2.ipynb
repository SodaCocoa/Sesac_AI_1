# %%
import pandas as pd 
df = pd.read_csv(r'C:\Users\bluecom011\Desktop\dataList\weather.csv')
#df.head(6)
#df.iloc[:3,2:4] #행과 열 사용할땐 iloc사용!
#df[['temp','mean_wind']]

col=df.columns
type(col)
#col.index('temp')
# Out:
# pandas.core.indexes.base.Index

# %%
import pandas as pd 
df = pd.read_csv(r'C:\Users\bluecom011\Desktop\dataList\weather.csv')
df[['temp','mean_wind']][:3] # [:숫자]로 갯수지정
# Out:
#    temp  mean_wind
# 0  28.7        3.4
# 1  25.2        3.8
# 2  22.1        2.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3653 entries, 0 to 3652
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       3653 non-null   object
#  1   temp       3653 non-null   float64
#  2   max_wind   3649 non-null   float64
#  3   mean_wind  3647 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 114.3+ KB

# %%
df.describe() #숫자 자료만 기술통계

df[['max_wind','mean_wind']].describe() #원하는값만 뽑아서 요약도 가능
# Out:
#           max_wind    mean_wind
# count  3649.000000  3647.000000
# mean      7.911099     3.936441
# std       3.029862     1.888473
# min       2.000000     0.200000
# 25%       5.700000     2.500000
# 50%       7.600000     3.600000
# 75%       9.700000     5.000000
# max      26.000000    14.900000

# %%
df['date'].describe() #문자 자료에 대한 기술통계도 가능함 (카운트만 가능)
#unique는 각자 다른값의 수
# Out:
# count           3653
# unique          3653
# top       2010-08-01
# freq               1
# Name: date, dtype: object

# %%
dfDescrbe=df.describe() 
dfDescrbe.iloc[[1,5],:] #describe로 나와있는거도 데이터 프레임 구조임
# Out:
#            temp  max_wind  mean_wind
# mean  12.942102  7.911099   3.936441
# 50%   13.800000  7.600000   3.600000

# %%
#전치 (가로세로 뒤집기)
dfDescrbe.T [['mean','50%']] 
# 왼쪽 인덱스 값들은 차트를 그릴떄 아래쪽 제목으로 사용가능
# Out:
#                 mean   50%
# temp       12.942102  13.8
# max_wind    7.911099   7.6
# mean_wind   3.936441   3.6

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,3))
plt.plot(dfDescrbe['temp'][1:]) #1번인 count를 제외하고 그후부터 보여줄거야
plt.plot(dfDescrbe['max_wind'][1:])
plt.plot(dfDescrbe['mean_wind'][1:])
#plt.show()
#plt.plot(df['max_wind'])

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,3))
plt.bar(dfDescrbe.index[1:],dfDescrbe['temp'][1:]) #1번인 count를 제외하고 그후부터 보여줄거야
plt.bar(dfDescrbe.index[1:],dfDescrbe['max_wind'][1:]) #bar 차트는 x,y축이 있어야함
plt.bar(dfDescrbe.index[1:],dfDescrbe['mean_wind'][1:]) #
# Out:
# <BarContainer object of 7 artists>

# %%
df=pd.read_csv(r'C:\Users\bluecom011\Desktop\dataList\bank.csv')
df.head()
# Out:
#            job  education  balance  duration   y
# 0   management   tertiary     2143       261  no
# 1   technician  secondary      265       348  no
# 2  blue-collar  secondary       -7       365  no
# 3   technician  secondary       -3      1666  no
# 4   technician  secondary     -103       145  no

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7234 entries, 0 to 7233
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   job        7190 non-null   object
#  1   education  6961 non-null   object
#  2   balance    7234 non-null   int64
#  3   duration   7234 non-null   int64
#  4   y          7234 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 282.7+ KB
#             balance     duration
# count   7234.000000  7234.000000
# mean    1374.912911   262.875311
# std     3033.882933   268.921065
# min    -3313.000000     0.000000
# 25%       74.000000   103.000000
# 50%      453.500000   183.000000
# 75%     1470.750000   321.750000
# max    81204.000000  3366.000000

# %%
plt.subplot(1,2,1)
plt.plot(df['duration'],'go')
plt.subplot(1,2,2)
plt.hist(df['duration'])
# Out:
# (array([5.544e+03, 1.197e+03, 3.080e+02, 1.100e+02, 4.300e+01, 2.200e+01,
#         2.000e+00, 3.000e+00, 3.000e+00, 2.000e+00]),
#  array([   0. ,  336.6,  673.2, 1009.8, 1346.4, 1683. , 2019.6, 2356.2,
#         2692.8, 3029.4, 3366. ]),
#  <BarContainer object of 10 artists>)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7234 entries, 0 to 7233
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   job        7190 non-null   object
#  1   education  6961 non-null   object
#  2   balance    7234 non-null   int64
#  3   duration   7234 non-null   int64
#  4   y          7234 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 282.7+ KB

# %%
df['job'].describe() #job에 대한 요약
#df[['job','y']].describe() #job과 y를 같이보고싶음
# Out:
# count           7190
# unique            11
# top       management
# freq            1560
# Name: job, dtype: object

# %%
###job의 유니크한 값은 무엇일까?
df['job'].unique()
# Out:
# array(['management', 'technician', 'blue-collar', 'retired', 'services',
#        'admin.', 'entrepreneur', 'self-employed', 'unemployed', 'student',
#        nan, 'housemaid'], dtype=object)

# %%
result=df['job'].value_counts()
#왼쪽이 인덱스 , 오른쪽이 value

plt.barh(result.index, result)
result
# Out:
# job
# management       1560
# blue-collar      1499
# technician       1206
# admin.            834
# services          661
# retired           351
# self-employed     256
# entrepreneur      239
# unemployed        223
# housemaid         208
# student           153
# Name: count, dtype: int64

# %%
###결측치 시각화

df.isnull().sum()
# Out:
# job           44
# education    273
# balance        0
# duration       0
# y              0
# dtype: int64

# %%
import seaborn as sns

sns.heatmap(df.isnull())
#아래를 보면 결측치를 볼수있음
# Out:
# <Axes: >

# %%
sns.countplot(data=df, x='y', hue='job')
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %%
#df.columns
df_corr=df[['balance','duration']].corr()
print(df_corr)
sns.heatmap(df_corr, annot=True, fmt=".2f", cmap="Blues")
#0.00934로 매우 작은 값이라 상관성이 없다고 봄
# Out:
#           balance  duration
# balance   1.00000   0.00934
# duration  0.00934   1.00000
# <Axes: >
