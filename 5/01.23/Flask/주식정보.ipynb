# %%
import pandas as pd
import lxml
url ='http://companyinfo.stock.naver.com/v1/company/c1010001.aspx?cmp_cd=005930'
datas = pd.read_html(url, encoding='utf-8')[12]
datas
# Out:
#        제공처      최종일자     목표가   직전목표가  변동률(%) 투자의견 직전투자의견
# 0       KB  24/01/18   95000   95000    0.00  BUY    BUY
# 1   DB금융투자  24/01/16   94000   94000    0.00  Buy    Buy
# 2     한화투자  24/01/16   94000   94000    0.00  Buy    Buy
# 3      현대차  24/01/16   89000   89000    0.00  BUY    BUY
# 4    IBK투자  24/01/16   90000   90000    0.00   매수     매수
# 5      메리츠  24/01/15   95000   95000    0.00  Buy    Buy
# 6     하이투자  24/01/10   87000   83000    4.82  Buy    Buy
# 7     NH투자  24/01/10   95000   95000    0.00  Buy    Buy
# 8     한국투자  24/01/10   99000   99000    0.00   매수     매수
# 9       흥국  24/01/10   93000   93000    0.00  BUY    BUY
# 10      삼성  24/01/10   95000   95000    0.00  BUY    BUY
# 11    DS투자  24/01/10   99000   99000    0.00  BUY    BUY
# 12   BNK투자  24/01/10   86000   82000    4.88   매수     매수
# 13    미래에셋  24/01/09  105000   90000   16.67   매수     매수
# 14    유진투자  24/01/09   93000   93000    0.00  BUY    BUY
# ...

# %%
import requests
from lxml import etree
# Your API URL
api_url ="https://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey=%3D%3D&pageNo=1&numOfRows=10&dataType=XML&dataCd=ASOS&dateCd=DAY&startDt=20100101&endDt=20100601&stnIds=108"
response = requests.get(api_url)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\r\n<response><header><resultCode>00</resultCode><resultMsg>NORMAL_SERVICE</resultMsg></header><body><dataType>XML</dataType><items><item><stnId>108</stnId><stnNm>\xec\x84\x9c\xec\x9a\xb8</stnNm><tm>2010-01-01</tm><avgTa>-7.6</avgTa><minTa>-12.7</minTa><minTaHrmt>0654</minTaHrmt><maxTa>-3.6</maxTa><maxTaHrmt>1501</maxTaHrmt><mi10MaxRn></mi10MaxRn><mi10MaxRnHrmt></mi10MaxRnHrmt><hr1MaxRn></hr1MaxRn><hr1MaxRnHrmt></hr1MaxRnHrmt><sumRnDur></sumRnDur><sumRn></sumRn><maxInsWs>7.5</maxInsWs><maxInsWsWd>340</maxInsWsWd><maxInsWsHrmt>0105</maxInsWsHrmt><maxWs>3.4</maxWs><maxWsWd>70</maxWsWd><maxWsHrmt>2350</maxWsHrmt><avgWs>1.9</avgWs><hr24SumRws>1608</hr24SumRws><maxWd>70</maxWd><avgTd>-16.9</avgTd><minRhm>30</minRhm><minRhmHrmt>1137</minRhmHrmt><avgRhm>48.0</avgRhm><avgPv>1.7</avgPv><avgPa>1010.6</avgPa><maxPs>1024.4</maxPs><maxPsHrmt>0005</maxPsHrmt><minPs>1019.4</minPs><minPsHrmt>2356</minPsHrmt><avgPs>1021.7</avgPs><ssDur>9.6</ssDur><sumSsHr>7.3</
# ...

# %%
import requests
from lxml import etree

# API URL

response = requests.get(api_url)

# XML 파싱
root = etree.fromstring(response.content)

# 데이터 추출 및 딕셔너리 변환
weather_data = []
for item in root.findall('.//item'):
    data = {
        'stnId': item.findtext('stnId'),
        'stnNm': item.findtext('stnNm'),
        'tm': item.findtext('tm'),
        'avgTa': item.findtext('avgTa'),
        'minTa': item.findtext('minTa'),
        'maxTa': item.findtext('maxTa'),
        # 필요한 다른 필드들을 여기에 추가하세요
    }
    weather_data.append(data)

# 결과 출력
print(weather_data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 23
#      13 for item in root.findall('.//item'):
#      14     data = {
#      15         'stnId': item.findtext('stnId'),
#      16         'stnNm': item.findtext('stnNm'),
#    (...)
#      21         # 필요한 다른 필드들을 여기에 추가하세요
#      22     }
# ---> 23     weather_data.append(data)
#      25 # 결과 출력
#      26 print(weather_data)
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
import requests
from lxml import etree

# Your API URL
api_url ="https://apis.data.go.kr/1360000/AsosDalyInfoService/getWthrDataList?serviceKey=f13VAts4dbhhtcMb2lWnStS2qRXBRFcX3mRK8DP5PxtmnvK0QTqIuCxDfDvTEJLG0cMJnCWDSho31XbxEg1tkQ%3D%3D&pageNo=1&numOfRows=10&dataType=XML&dataCd=ASOS&dateCd=DAY&startDt=20100101&endDt=20100601&stnIds=108"
response = requests.get(api_url)

# Parse the XML
root = etree.fromstring(response.content)

# Function to convert each XML element to a dictionary
def xml_to_dict(element):
    return {child.tag: child.text for child in element}

# Process all elements and convert them to dictionaries
records = [xml_to_dict(child) for child in root]

# Now records is a list of dictionaries
print(records)
# Out:
# [{'resultCode': '00', 'resultMsg': 'NORMAL_SERVICE'}, {'dataType': 'XML', 'items': None, 'numOfRows': '10', 'pageNo': '1', 'totalCount': '152'}]

# %%
datas = datas.to_dict(orient="records")
datas
# Out:
# [{'제공처': 'KB',
#   '최종일자': '24/01/18',
#   '목표가': 95000,
#   '직전목표가': 95000,
#   '변동률(%)': 0.0,
#   '투자의견': 'BUY',
#   '직전투자의견': 'BUY'},
#  {'제공처': 'DB금융투자',
#   '최종일자': '24/01/16',
#   '목표가': 94000,
#   '직전목표가': 94000,
#   '변동률(%)': 0.0,
#   '투자의견': 'Buy',
#   '직전투자의견': 'Buy'},
#  {'제공처': '한화투자',
#   '최종일자': '24/01/16',
#   '목표가': 94000,
#   '직전목표가': 94000,
#   '변동률(%)': 0.0,
#   '투자의견': 'Buy',
#   '직전투자의견': 'Buy'},
#  {'제공처': '현대차',
#   '최종일자': '24/01/16',
#   '목표가': 89000,
#   '직전목표가': 89000,
#   '변동률(%)': 0.0,
#   '투자의견': 'BUY',
#   '직전투자의견': 'BUY'},
#  {'제공처': 'IBK투자',
#   '최종일자': '24/01/16',
#   '목표가': 90000,
#   '직전목표가': 90000,
#   '변동률(%)': 0.0,
#   '투자의견': '매수',
#   '직전투자의견': '매수'},
#  {'제공처': '메리츠',
#   '최종일자': '24/01/15',
#   '목표가': 95000,
#   '직전목표가': 95000,
#   '변동률(%)': 0.0,
#   '투자의견': 'Buy',
#   '직전투자의견': 'Buy'},
#  {'제공처': '하이투자',
#   '최종일자': '24/01/10',
#   '목표가': 87000,
#   '직전목표가': 83000,
#   '변동률(%)': 4.82,
#   '투자의견': 'Buy',
#   '직전투자의견': 'Buy'},
# ...
