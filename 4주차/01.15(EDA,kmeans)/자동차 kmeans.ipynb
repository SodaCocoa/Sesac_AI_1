# %%
# pandas 패키지 임포트
import pandas as pd

# read_excel() 함수를 이용하여 파일 불러오기
data = pd.read_csv(r'C:\Users\bluecom011\Desktop\1월\4주차\01.15\Auto Sales data.csv')

# 데이터 몇 행만 보기
data.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10168               36      96.66                1  3479.76
#
#     ORDERDATE  DAYS_SINCE_LASTORDER   STATUS  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0  24/02/2018                   828  Shipped  Motorcycles    95    S10_1678
# 1  07/05/2018                   757  Shipped  Motorcycles    95    S10_1678
# 2  01/07/2018                   703  Shipped  Motorcycles    95    S10_1678
# 3  25/08/2018                   649  Shipped  Motorcycles    95    S10_1678
# 4  28/10/2018                   586  Shipped  Motorcycles    95    S10_1678
#
#            CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# ...

# %%
# 수치형 컬럼명 변경
new_column_names = {'QUANTITYORDERED': '주문수량',
                    'PRICEEACH': '개당가격',
                    'ORDERLINENUMBER': '로트번호',
                    'SALES': '판매액',
                    'MSRP': '제조사권장 소비자가격'}
data.rename(columns=new_column_names, inplace=True)

# %%
# 컬럼명 변경
new_column_names2 = {'STATUS': '주문상태',
                    'PRODUCTLINE': '제품라인',
                    'PRODUCTCODE': '제품코드',
                    'CUSTOMERNAME': '고객명',
                    'CITY': '도시',
                    'POSTALCODE': '우편번호',
                    'COUNTRY': '국가',
                    'DEALSIZE': '거래규모',
                    'ORDERDATE': '주문일자',
                    'ADDRESSLINE1':'주소'}
data.rename(columns=new_column_names2, inplace=True)

# %% [markdown]
# 사용하지 않는 컬럼은 제거

# %%
data = data.drop('ORDERNUMBER',axis=1)

# %%
data = data.drop('PHONE',axis=1)

# %%
data = data.drop('CONTACTLASTNAME',axis=1)

# %%
data = data.drop('CONTACTFIRSTNAME',axis=1)

# %%
data = data.drop('DAYS_SINCE_LASTORDER',axis=1)

# %%
data.head(5)
# Out:
#    주문수량   개당가격  로트번호      판매액        주문일자     주문상태         제품라인  제조사권장 소비자가격  \
# 0    30  95.70     2  2871.00  24/02/2018  Shipped  Motorcycles           95
# 1    34  81.35     5  2765.90  07/05/2018  Shipped  Motorcycles           95
# 2    41  94.74     2  3884.34  01/07/2018  Shipped  Motorcycles           95
# 3    45  83.26     6  3746.70  25/08/2018  Shipped  Motorcycles           95
# 4    36  96.66     1  3479.76  28/10/2018  Shipped  Motorcycles           95
#
#        제품코드                   고객명                             주소          도시  \
# 0  S10_1678     Land of Toys Inc.        897 Long Airport Avenue         NYC
# 1  S10_1678    Reims Collectables             59 rue de l'Abbaye       Reims
# 2  S10_1678       Lyon Souveniers  27 rue du Colonel Pierre Avia       Paris
# 3  S10_1678     Toys4GrownUps.com             78934 Hillside Dr.    Pasadena
# 4  S10_1678  Technics Stores Inc.              9408 Furth Circle  Burlingame
#
#       우편번호      국가    거래규모
# ...

# %%
# 필요 패키지 불러오기 (KMeans, matplotlib, preprocessing)
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn import preprocessing

# 원본 데이터를 복사해서 전처리하기 (원본 데이터를 가지고 바로 전처리하지 않는다)
processed_data = data.copy()

# # 데이터 전처리 - 정규화를 위한 작업
# scaler = preprocessing.MinMaxScaler()
# processed_data[['ItemsBought', 'ItemsReturned']] = scaler.fit_transform(processed_data[['ItemsBought', 'ItemsReturned']])

# 화면(figure) 생성
plt.figure(figsize = (10, 6))

# %%
# 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# K 값을 늘려가며 반복 테스트
for i in range(1, 7):
    # 클러스터 생성
    estimator = KMeans(n_clusters=i)
    ids = estimator.fit_predict(processed_data[['개당가격', '판매액']])
    # 2행 3열을 가진 서브플롯 추가 (인덱스 = i)
    plt.subplot(3, 2, i)
    plt.tight_layout()
    # 서브플롯의 라벨링
    plt.title("K value = {}".format(i))
    plt.xlabel('개당가격')
    plt.ylabel('판매액')
    # 클러스터링 그리기
    plt.scatter(processed_data['개당가격'], processed_data['판매액'], c=ids)  
plt.show()
# Out:
# c:\Users\bluecom011\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bluecom011\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1440: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=11.
#   warnings.warn(
# c:\Users\bluecom011\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %%
# K = 2로 클러스터링
estimator = KMeans(n_clusters=2)

# 클러스터링 생성
cluster_ids = estimator.fit_predict(processed_data[['개당가격', '판매액']])

# create a scatter plot
plt.scatter(processed_data['개당가격'], processed_data['판매액'], c=cluster_ids, cmap='viridis')

# # 제품과 클러스터 id로 데이터에 범례 달기
# for index, (bought, returned, zip_code, product) in processed_data[['주문수량', '판매액', '우편번호', '제품코드']].iterrows():
#     plt.annotate("{}: Clu{}".format(product, cluster_ids[index]), (bought, returned), textcoords="offset points", xytext=(0,5), ha='center')

plt.xlabel('개당가격')
plt.ylabel('판매액')
plt.title('개당가격과 판매액에 대한 클러스터링')
plt.show()
# Out:
# c:\Users\bluecom011\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bluecom011\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1440: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=11.
#   warnings.warn(

# %%
# 클러스터 1로 분류된 데이터를 추출해보자
data[ cluster_ids == 1 ]
# Out:
#       주문수량    개당가격  로트번호      판매액        주문일자     주문상태         제품라인  \
# 0       30   95.70     2  2871.00  24/02/2018  Shipped  Motorcycles
# 1       34   81.35     5  2765.90  07/05/2018  Shipped  Motorcycles
# 2       41   94.74     2  3884.34  01/07/2018  Shipped  Motorcycles
# 3       45   83.26     6  3746.70  25/08/2018  Shipped  Motorcycles
# 4       36   96.66     1  3479.76  28/10/2018  Shipped  Motorcycles
# ...    ...     ...   ...      ...         ...      ...          ...
# 2741    42   97.16     5  4080.72  21/11/2019  Shipped        Ships
# 2742    20  112.22    15  2244.40  02/12/2019  Shipped        Ships
# 2743    29  137.19     1  3978.51  31/01/2020  Shipped        Ships
# 2745    34   62.24     1  2116.16  28/03/2020  Shipped        Ships
# 2746    47   65.52     9  3079.44  06/05/2020  On Hold        Ships
#
#       제조사권장 소비자가격      제품코드                      고객명  \
# 0              95  S10_1678        Land of Toys Inc.
# ...

# %%
unique_countries = processed_data['국가'].nunique()
print("고유 국가의 갯수:", unique_countries)
# Out:
# 고유 국가의 갯수: 19

# %%
# K = 2로 클러스터링
estimator = KMeans(n_clusters=2)

# 클러스터링 생성
cluster_ids = estimator.fit_predict(processed_data[['개당가격', '주문수량']])

# 국가 정보를 가져오기
countries = processed_data['국가'].unique()

# 각 국가별로 서브플롯을 생성하여 클러스터링 결과 플로팅
for country in countries:
    country_data = processed_data[processed_data['국가'] == country]
    
    plt.scatter(country_data['개당가격'], country_data['주문수량'], label=country, c=cluster_ids[country_data.index])

    # # 제품과 클러스터 id로 데이터에 범례 달기
    # for index, (bought, returned, zip_code, product) in country_data[['주문수량', '판매액', '우편번호', '제품코드']].iterrows():
    #     plt.annotate("{}: Clu{}".format(product, cluster_ids[index]), (bought, returned), textcoords="offset points", xytext=(0,5), ha='center')

    plt.xlabel('개당가격')
    plt.ylabel('주문수량')
    plt.title('국가별 주문수량과 주문수량에 대한 클러스터링')
    plt.legend()
    plt.show()
# Out:
# c:\Users\bluecom011\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# c:\Users\bluecom011\miniconda3\envs\OpenAI\Lib\site-packages\sklearn\cluster\_kmeans.py:1440: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=11.
#   warnings.warn(
